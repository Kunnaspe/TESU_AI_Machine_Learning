# %%
import numpy as np
from matplotlib import pyplot as plt

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)

fig, ax = plt.subplots()

# Scatter plot
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale) * 500)
ax.set(title="Some random data, created with JupyterLab!")

plt.show()

# %%
print("hello world")
# Out:
# hello world

# %%
# My first jupyter notebook

# %% [markdown]
# # A first level heading
# ## A second level heading
# ## A third level heading

# %% [markdown]
# To live is **bold**.

# %% [markdown]
# Live *boldly with style*

# %% [markdown]
# >We should only fear, fear itself

# %% [markdown]
# 1. One
# 2. Two
# 3. Three

# %% [markdown]
# * One
# * Two
# * Three

# %% [markdown]
# At the command prompt, `git command`

# %% [markdown]
# For a useful markup guide, clink on this link, <https://www.markdownguide.org/basic-syntax/>

# %% [markdown]
# !(https://images.pexels.com/photos/5034542/pexels-photo-5034542.jpeg)
